# %% [markdown]
# Importing the Dependeincies

# %%
 import numpy as np
 #numpy is usefull to making arrays 
 import pandas as pd
 from sklearn.model_selection import train_test_split
 # train_test_split fuction allows to split data into training data and test dataa
 from sklearn.linear_model import LogisticRegression
 from sklearn.metrics import accuracy_score
 #accuracy_score model will help to check the accuracy of model

# %%
#loading the dataset to a Pandas Dataframe
credit_card_data = pd.read_csv('/content/creditcard.csv.zip')

# %%
#first 5 rows of the dataset
credit_card_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-41664562821c> in <module>
#       1 #first 5 rows of the dataset
# ----> 2 credit_card_data.head()
#
# NameError: name 'credit_card_data' is not defined

# %%
#first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
  #last five rows of data
  cradit_cad_data.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ad67f54953ea> in <module>
#       1 #last five rows of data
# ----> 2 cradit_cad_data.tail()
#
# NameError: name 'cradit_cad_data' is not defined

# %%
# last five rows of data
  credit_card_data.tail()
# Out:
#   File "<ipython-input-16-9fb06d8cf716>", line 2
#     credit_card_data.tail()
#     ^
# IndentationError: unexpected indent

# %%
# last five rows of data
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
# dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# checking the no. of missing values in each column
credit_card_data.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of          Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 284802  False  False  False  False  False  False  False  False  False  False
# 284803  False  False  False  False  False  False  False  False  False  False
# 284804  False  False  False  False  False  False  False  False  False  False
# 284805  False  False  False  False  False  False  False  False  False  False
# ...

# %%
# distribution of legit transactions and fraudulent transaction
credit_card_data['class'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# distribution of legit transactions and fraudulent transaction
credit_card_data['class'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# distribution of legit transactions and fraudulent transaction
credit_card_data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# This dataset is highly unblanced

# %% [markdown]
# 0->Normal Transaction
# 1-> fraudulent Transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
# legit and fraud is Panda series datatype
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
#statistical measures of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
 fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
 # comare the values for both transections
 credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Buid a sample dataset containing similar distribution of normal trabsactions and fraudulent Transections
#
# Number of Fraudulent Transactions->492

# %%
 legit_sample = legit.sample1(n= 492)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-67c3463156eb> in <module>
# ----> 1 legit_sample = legit.sample1(n= 492)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sample1'

# %%
legit_sample = legit.sample(n= 492)

# %%
 Concatenating two DataFrames
# Out:
#   File "<ipython-input-33-41581c282d2b>", line 1
#     Concatenating two DataFrames
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
#  Concatenating two DataFrames

# %%
  new_dataset = pd.concat([legit_sample,fraud],axis = 0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 272030  164878.0  2.015783  0.104244 -1.830064  0.355767  0.337155 -1.020142
# 146335   87616.0  1.974364 -0.388903 -2.801592 -1.152844  1.460662  0.579483
# 201700  133997.0  0.276797  1.153321  0.140114  1.186947  0.514968 -0.476863
# 24799    33388.0  1.291987  0.116532 -0.451977  0.133746  0.600175  0.680262
# 252227  155711.0 -0.446586  1.645575 -1.269729  1.224403 -0.362184  1.587148
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 272030  0.163267 -0.218308  0.387549  ...  0.230140  0.770189 -0.079115
# 146335  0.372566  0.182079  0.316463  ...  0.404278  1.404522 -0.004893
# 201700  0.732327 -0.190412 -0.767250  ... -0.187020 -0.339970  0.158458
# 24799  -0.219814  0.266643  0.084527  ... -0.337201 -1.027677 -0.051240
# 252227 -3.199591 -7.859430 -0.868728  ... -3.239043  2.993490  0.219939
#
# ...

# %%
 new_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
  new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      93423.745935 -0.194269 -0.002811  0.039512 -0.049550  0.039164
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.052073  0.077954 -0.055076 -0.115684  ...  0.008406 -0.034836
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.044939 -0.005584  0.028225  0.009557 -0.037254  0.030647  0.015962
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       98.369898
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
print(new_dataset.shape)
print(fraud.shape)
print(legit_sample.shape)
# Out:
# (984, 31)
# (492, 31)
# (492, 31)

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
fraud.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
legit_sample.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 272030  164878.0  2.015783  0.104244 -1.830064  0.355767  0.337155 -1.020142
# 146335   87616.0  1.974364 -0.388903 -2.801592 -1.152844  1.460662  0.579483
# 201700  133997.0  0.276797  1.153321  0.140114  1.186947  0.514968 -0.476863
# 24799    33388.0  1.291987  0.116532 -0.451977  0.133746  0.600175  0.680262
# 252227  155711.0 -0.446586  1.645575 -1.269729  1.224403 -0.362184  1.587148
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 272030  0.163267 -0.218308  0.387549  ...  0.230140  0.770189 -0.079115
# 146335  0.372566  0.182079  0.316463  ...  0.404278  1.404522 -0.004893
# 201700  0.732327 -0.190412 -0.767250  ... -0.187020 -0.339970  0.158458
# 24799  -0.219814  0.266643  0.084527  ... -0.337201 -1.027677 -0.051240
# 252227 -3.199591 -7.859430 -0.868728  ... -3.239043  2.993490  0.219939
#
# ...

# %%
print(credit_card_data.shape)
# Out:
# (284807, 31)

# %% [markdown]
# Splitting the data into Features and Targets

# %%
X = new_dataset.drop(columns = 'Class',axis =1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 272030  164878.0  2.015783  0.104244 -1.830064  0.355767  0.337155 -1.020142
# 146335   87616.0  1.974364 -0.388903 -2.801592 -1.152844  1.460662  0.579483
# 201700  133997.0  0.276797  1.153321  0.140114  1.186947  0.514968 -0.476863
# 24799    33388.0  1.291987  0.116532 -0.451977  0.133746  0.600175  0.680262
# 252227  155711.0 -0.446586  1.645575 -1.269729  1.224403 -0.362184  1.587148
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 272030    0
# 146335    0
# 201700    0
# 24799     0
# 252227    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# Split the data into Training data and Testing Data

# %%
 X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2, stratify, random_state = 2)
# Out:
#   File "<ipython-input-51-79e1d9c358e2>", line 1
#     X_train, X_test, Y_train, Y_test = train_test_spit(X,Y,test_size=0.2, stratify, random_state = 2)
#                                                                          ^
# SyntaxError: positional argument follows keyword argument

# %%
  X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2, stratify = Y, random_state = 2)

# %%
print(X.shape,X_train.shape, X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# Modal Training
#
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the logistic Regression model with Training Data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
# Out:
#   File "<ipython-input-63-b2f2b8c11f56>", line 1
#     Model Evalution
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# Model Evalution
#
#   Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data: ', training_data_accuracy)
# Out:
# Accuracy on Training data:  0.9390088945362135

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9238578680203046
